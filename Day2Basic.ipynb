# %% [markdown]
# <a href="https://colab.research.google.com/github/Sia-DataScience/Python---foundation---manual-/blob/main/Day2Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Escape sequence character
A= " This is string. \nwe are creating it in a python"
B=" This is string.\t we are creating it in python"
print(A)
print(B)
# Out:
#  This is string.
# we are creating it in a python
#  This is string.	 we are creating it in python

# %%
# concatenation
Str1= "Hello"
Str2= "world"
finatstr  = (Str1+Str2)
print (finatstr)
# Out:
# Helloworld

# %%
# length of string
Str1= "Hello"
Str2= "world"
print(len(Str1))
print(len(Str2))
print(len(Str1+Str2))
# Out:
# 5
# 5
# 10

# %%
# Indexing
str="apna_collage"
Val=str[4]
print(Val)
print(str[5])
# Out:
# _
# c

# %%
#slicing
str="apna_collage"
print(str[3:8])
print(str[:5])
print(str[5:])
#Negative slicing
print(str[-5:-1])
# Out:
# a_col
# apna_
# collage
# llag

# %%
# string function
str="this am a coder"
str=str.capitalize()
print(str.endswith("er"))
print(str.endswith("age"))
print(str)
# Out:
# True
# False
# This am a coder

# %%
str="I am learning python"
print(str.replace("python","JavaScript"))#we can replace any alphabet also
val=" I am going to appna collage"
print(val.replace("o","t"))
# Out:
# I am learning JavaScript
#  I am gting tt appna ctllage

# %%
#to find the character or word
str= "Iam from studying python from apna college"
print(str.find("from"))
# if you search for any character or word that is not present in our string then it will return us negative index
print(str.count("from"))
print(str.count("m"))
# Out:
# 4
# 2
# 3

# %%
#WAP to input user's first name and print it's length
str=input("User's first names")
print(" length of your string is:",len(str))
print(str.count("s"))
# Out:
# User's first namesShrawani Vilas Chaudhari
#  length of your string is: 25
# 1

# %%
#conditional statement
age= 21
if(age>=18):
    print("can vote")
    print ("can drive")
# Out:
# can vote
# can drive

# %%
Light="Blue"# we are using indentation
if(Light=="red"):#which means giving proper spaces
    print("stop")# it is imp in python
elif(Light=="green"):# here we gave 4 spaces
    print(" go")
elif (Light=="yellow"):
    print("wait")
else:
    print("light is broken")

print("end of the code")
# Out:
# light is broken
# end of the code

# %%
#Grade student on the basis of their grades
marks= int(input("enter your marks :"))
if(marks>=90):
    print("grade=A")
elif ( 90>marks>=80):
    print(" grade=B")
elif(80>marks>=70):
    print("grade=C")
elif(70>marks>=60):
    print("grade=D")
else:
    print(" Need to study hard")
# Out:
# enter your marks :52
#  Need to study hard

# %%
# Nesting
age = int( input (" your age"))
if(age>=18):
    if(age>=80):
        print("cannot drive")
    else:
        print("can drive")
else:
    print(" cannot drive")
# Out:
#  your age45
# can drive

# %%
#WAP to check if the numbers enter by the user is odd or even
number =  int( input ( " enter your no:- "))
if ( number % 2 == 0):
    print(" even ")
else:
    print (" odd")
# Out:
#  enter your no:- 8
#  even

# %%
# WAP to find the greatest of 3  number enter by the user
a= int (input("no1"))
b= int(input("no2"))
c= int( input( " no3"))
if(a>b and a> c):
    print (" a is greatest")
elif(b>c):
    print("b is greatest")
else:
    print(" c is greatest")
# Out:
# no145
# no267
#  no328
# b is greatest

# %%
# WAP to check if  a number is a multiple of 7
x= int( input(" number"))
if( x%7==0):
    print(" yes")
else:
    print(" no")
# Out:
#  number14
#  yes

# %%
#HW
a= int( input(" no1"))
b = int( input(" no2"))
c=int(input(" no3"))
d = int( input(" no3"))
if( a>b and a>c and a>d):
    print (" ais greatest")
elif (b>c and b> d ):
    print (" b is greatest")
elif ( c> d):
    print (" c is greatest")
else:
    print(" d is greatest")
# Out:
#  no16
#  no218
#  no338
#  no34
#  c is greatest

# %%
# lift  instructions
weight= int( input ( " enter your no."))
if( weight> 400):
    print (" Danger! Overweight. Elevator will not move")
elif(weight==400):
    print (" Warning! Maximum capacity reach. Priveeywith caution")
else:
    print (" safe to go! Door closing")
# Out:
#  enter your no.477
#  Danger! Overweight. Elevator will not move

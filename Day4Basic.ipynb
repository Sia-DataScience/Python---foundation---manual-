# %% [markdown]
# <a href="https://colab.research.google.com/github/Sia-DataScience/Python---foundation---manual-/blob/main/Day4Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dictionary in python
dict={
    "name" : "shrawani",
    "subjects" : ["python","c++","java"],
    "topics":("variable","sets"),
    "age":19,
    "is_adult":True,
    12.5:99
}
dict["name"]="amruta"
dict["surmane"]="Choudhary"
print(type(dict))
print (dict["name"])
print (dict["age"])
print (dict["subjects"])
print (dict["topics"])
print (dict["is_adult"])
print(dict)
# Out:
# <class 'dict'>
# amruta
# 19
# ['python', 'c++', 'java']
# ('variable', 'sets')
# True
# {'name': 'amruta', 'subjects': ['python', 'c++', 'java'], 'topics': ('variable', 'sets'), 'age': 19, 'is_adult': True, 12.5: 99, 'surmane': 'Choudhary'}

# %%
# nested dictionary
Student={
    "name":"shrawani chaudhari",
    "subjects":{
        "phy":97,
        "chem":98,
        "maths":95
    }
}
print(Student)
print (Student ["subjects"]["phy"])
print (Student ["subjects"]["chem"])
print (Student ["subjects"]["maths"])
print((list(Student.keys())))# return all keys
print(list(Student.values()))#return all value
print(list(Student.items()))#return all ( key,value ) pairs as a tuple
pair= list(Student.items())
print(pair[1])
#print(Students["name2"])it will give error
print(Student.get("name2"))# none if key is wrong
new_dict={"city":"delhi","age":19}
Student.update(new_dict)
print(Student)
# Out:
# {'name': 'shrawani chaudhari', 'subjects': {'phy': 97, 'chem': 98, 'maths': 95}}
# 97
# 98
# 95
# ['name', 'subjects']
# ['shrawani chaudhari', {'phy': 97, 'chem': 98, 'maths': 95}]
# [('name', 'shrawani chaudhari'), ('subjects', {'phy': 97, 'chem': 98, 'maths': 95})]
# ('subjects', {'phy': 97, 'chem': 98, 'maths': 95})
# None
# {'name': 'shrawani chaudhari', 'subjects': {'phy': 97, 'chem': 98, 'maths': 95}, 'city': 'delhi', 'age': 19}

# %%
Collection= {1,2,2,"Hello", "world","world",4}
print (Collection)
print (len(Collection))
# Out:
# {'Hello', 2, 1, 'world', 4}
# 5

# %%
Collection= set()
Collection.add(1)
Collection.add("shrawani")
Collection.add("Chaudhari")
Collection.remove("Chaudhari")
Collection.clear()
print (Collection)
print ( type (Collection))
# Out:
# set()
# <class 'set'>

# %%
Group={"Hello","women","coding","python","apnacollege "}
print (Group.pop())
print (Group.pop())
print (Group.pop())
# Out:
# Hello
# apnacollege
# coding

# %%
Set1={1,2,3}
Set2={2,3,4}
print(Set2.union(Set1))
print (Set2.intersection(Set1))
# Out:
# {1, 2, 3, 4}
# {2, 3}

# %%
#Que1)
House={
    "Cat":"a small animal",
    "Table":["a piece of furniture","list of facts & figures"]
}
print(House)
# Out:
# {'Cat': 'a small animal', 'Table': ['a piece of furniture', 'list of facts & figures']}

# %%
#que2
Students={"python","java","c++","python","JavaScript","java","python","java","c++","c","JavaScript"}
print("The no of classroom needed:",len(Students))
# Out:
# The no of classroom needed: 5

# %%
#que3)
Mark ={}
X=int(input ("phy:"))
Mark.update({"phy":X})
X=int(input ("Chem:"))
Mark.update({"Chem":X})
X=int(input ("maths:"))
Mark.update({"maths":X})
print (Mark)
# Out:
# phy:98
# Chem:97
# maths:96
# {'phy': 98, 'Chem': 97, 'maths': 96}

# %%
Dict={
    ("float",9.0),
    ("Int",9)
}
print (Dict)
# Out:
# {('Int', 9), ('float', 9.0)}

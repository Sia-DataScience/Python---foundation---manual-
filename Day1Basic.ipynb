# %% [markdown]
# <a href="https://colab.research.google.com/github/Sia-DataScience/Python---foundation---manual-/blob/main/Day1Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("my name is shrawani chaudhari")
# Out:
# my name is shrawani chaudhari

# %%
print("My age is 18 ")
# Out:
# My age is 18

# %%
print(27)
# Out:
# 27

# %%
print(25+45)
# Out:
# 70

# %%
name = "Shrawani"
age = 18
age2=age
price= 25.88
print(name)
print(age)
print(age2)
print(price)
# Out:
# Shrawani
# 18
# 18
# 25.88

# %%
print(" My name is : ", name)
print("My age is :", age)
# Out:
#  My name is :  Shrawani
# My age is : 18

# %%
print(type(name))
print(type(age))
print(type(price))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
old=False
A= None
print (type(old))
print(type(A))
# Out:
# <class 'bool'>
# <class 'NoneType'>

# %%
a=4
b=5
sum= a+b
print(sum)
diff= a-b
print(diff)
# Out:
# 9
# -1

# %%
print ("i want to become a engineering")
# print ("i want to become a engineering")
# Out:
# i want to become a engineering

# %%
# arithmatic operators
a=5
b=2
print(a+b)#addition
print(a-b)#substraction
print(a*b)#multiply
print(a/b)#divide
print(a%b)#remainder finding
print(a**b)#a^b
# Out:
# 7
# 3
# 10
# 2.5
# 1
# 25

# %%
#relational operator
a=25
b=45
print(a==b)#False
print(a!=b)#True
print(a<=b)#True
print(a>=b)#False
print(a>b)#False
print(a<b)#True
# Out:
# False
# True
# True
# False
# False
# True

# %%
#assignment operator
num= 10
num+=5
print("num", num)
sat=10
sat-=3
print(" sat",sat)
Max= 10
Max**= 5
print(" Max",Max)#100000
# Out:
# num 15
#  sat 7
#  Max 100000

# %%
#Logical operator
a=50
b=20
print(not(a>b))#false
print(not (a<b))#True
print("AND operator:",(a==b)and(a>=b))
print("AND operator:",(a>b) and (a>=b))
print("OR Operator:",(a==b)or(a>=b))
print("OR Operator:",(a<b)or(a==b))
# Out:
# False
# True
# AND operator: False
# AND operator: True
# OR Operator: True
# OR Operator: False

# %%
#Type conversion ( automatic)
a=2
b=4.25
print(a+b)#6.25float
print(type(a+b))# floating
# Out:
# 6.25
# <class 'float'>

# %%
#Type casting ( manually)
a=int("2")
b = 4.25
print(a+b)#6.25
print(type(a+b))# float
print ( type(a))
# Out:
# 6.25
# <class 'float'>
# <class 'int'>

# %%
# Input in python
Val= input(" enter name:")
print("welcome",Val)
print( type( Val),Val)
# Out:
#  enter name:Shrawani
# welcome Shrawani
# <class 'str'> Shrawani

# %%
# type casting in input
Val= int(input( "enter some value:"))
print(" you have entered:",Val)
print ( type (Val))
# Out:
# enter some value:25
#  you have entered: 25
# <class 'int'>

# %%
name= input(" enter name ")
Age= input( "enter age")
percentage= input( " enter percentile")
print("welcome:", name)
print("age :",Age)
print ("percentile:", percentage)
# Out:
#  enter name Shrawani
# enter age19
#  enter percentile89.0027
# welcome: Shrawani
# age : 19
# percentile: 89.0027

# %%
#practice question
# write a program to input2 numbers and print their sum
Val1=int(input("enter no1"))
Val2= int(input("enter no2"))
print(" sum:",Val1+Val2)
# Out:
# enter no125
# enter no245
#  sum: 70

# %%
#WAP to input side of square and print it's area
Side=int(input("length of side:-"))
print ("area of square:-",(Side*Side))
# Out:
# length of side:-5
# area of square:- 25

# %%
# WAP to input 2 floating point number and their average
No1= float( input ("a"))
No2=float(input("b"))
print("sum:",(No1+No2)/2)
# Out:
# a4.2
# b8.2
# sum: 6.199999999999999

# %%
#4
No1= int(input ("a:-"))
No2=int(input ("b:-"))
print(No1>=No2)
print (No1<=No2)
# Out:
# a:-20
# b:-10
# True
# False

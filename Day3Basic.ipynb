# %% [markdown]
# <a href="https://colab.research.google.com/github/Sia-DataScience/Python---foundation---manual-/blob/main/Day3Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# list in python
marks = [ 95.7,84.6,98.6,90.6,94.8]
print ( marks)
print(marks[0])
print(marks[4])
print(len(marks))
print(type(marks))
# Out:
# [95.7, 84.6, 98.6, 90.6, 94.8]
# 95.7
# 94.8
# 5
# <class 'list'>

# %%
Students=["shrawani",89,19,"pune"]
print (Students [3])
Students [0]=" Amruta"
print(Students)
# Out:
# pune
# [' Amruta', 89, 19, 'pune']

# %%
#list slicing
marks=[56,67,45,84,98,37,96]
print(marks[1:4])
print(marks [:6])
print (marks[3:] )
# Out:
# [67, 45, 84]
# [56, 67, 45, 84, 98, 37]
# [84, 98, 37, 96]

# %%
# list method
list= [2,1,3]
print(list.append(4))
print(list.sort(reverse=True))

print(list.reverse())
print(list.insert(1,7))
print (list)
# sorting and appending is also possible with alphabets
val=["a","g","j","z","s"]
print( val.append("l"))
print (val.sort())
print(val)
# Out:
# None
# None
# None
# None
# [1, 7, 2, 3, 4]
# None
# None
# ['a', 'g', 'j', 'l', 's', 'z']

# %%
list = [1,2,1,3]
print(list.remove(1))
print (list.pop(2))
print(list)
# Out:
# None
# 3
# [2, 1]

# %%
# tuple
tup=(1,2,3,4)
print(tup)
print (tup[2])
print(tup[1])
print(type(tup))
# Out:
# (1, 2, 3, 4)
# 3
# 2
# <class 'tuple'>

# %%
#sigle element in tuple
tup=(1,)
print(type(tup))
print(tup)
# Out:
# <class 'tuple'>
# (1,)

# %%
#slicing in tuple
tup=( 1,2,3,4,5)
print(tup[1:4])
# Out:
# (2, 3, 4)

# %%
#tuple method
tup= (2,3,1,2,1,3)
print (tup.index(1))
print(tup.count(1))
# Out:
# 2
# 2

# %%
#que
movie=[]
movie1= input("no1:-")
movie2=input("no2:-")
movie3=input("no3:-")
print(movie.append(movie1))
print(movie.append(movie2))
print(movie.append(movie3))
print("your 3 favourite movie are:-", movie)
# Out:
# no1:-3 idiot
# no2:-Spyx family
# no3:-Demon slayer
# None
# None
# None
# your 3 favourite movie are:- ['3 idiot ', 'Spyx family ', 'Demon slayer ']

# %%
#que2
list1= [1,2,3,2,1]
copylist1=(list1.copy())
print(copylist1.reverse())
if(list1==copylist1):
    print("palindrome")
else:
    print("not a palindrome")

list2= [1,"abc","abc",1]
copylist2=list2.copy()
print (copylist2. reverse)
if(list2==copylist2):
    print ("palindrome")
else:
    print(" not a palindrome")
# Out:
# None
# palindrome
# <built-in method reverse of list object at 0x7a0cd195a840>
# palindrome

# %%
#que
tup =("C","D","A","A","B","B","A")
print(tup.count("A"))
list=[]
print(list.append(tup))

print(list)
# Out:
# 3
# None
# [('C', 'D', 'A', 'A', 'B', 'B', 'A')]

# %%
tup =["C","D","A","A","B","B","A"]
print(tup.sort())
print (tup)
# Out:
# None
# ['A', 'A', 'A', 'B', 'B', 'C', 'D']
